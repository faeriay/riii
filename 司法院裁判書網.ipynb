# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
#NOTE OF Select:http://sqa.stackexchange.com/questions/1355/what-is-the-correct-way-to-select-an-option-using-seleniums-python-webdriver
import time
from bs4 import BeautifulSoup

driver = webdriver.Firefox()
driver.get("http://jirs.judicial.gov.tw/FJUD/FJUDQRY01_1.aspx")
try:
    Select(driver.find_element_by_name("v_court")).select_by_visible_text(u"臺灣士林地方法院")
    #driver.findElement(By.xpath("//[@name='v_sys'][@value='A']")).click()
    #selenium.click("xpath=(//input[@type='checkbox'])[last()]");
    driver.find_element_by_xpath("//input[@name='v_sys' and @value='V']").click()
    driver.find_element_by_id("jmain1").clear()
    driver.find_element_by_id("jmain1").send_keys(u"離婚")
    driver.find_element_by_name("Button").click()
    print driver.page_source
    time.sleep(10)
    driver.close()
except:
    driver.close()
    print "error"
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.0 Transitional//EN">
# <html xmlns="http://www.w3.org/1999/xhtml"><head>
# 		<title>裁判書查詢</title>
# 		<meta content="Microsoft Visual Studio .NET 7.1" name="GENERATOR" />
# 		<meta content="C#" name="CODE_LANGUAGE" />
# 		<meta content="JavaScript" name="vs_defaultClientScript" />
# 		<meta content="http://schemas.microsoft.com/intellisense/ie5" name="vs_targetSchema" />
# 		<meta content="text/html; charset=UTF-8" http-equiv="Content-Type" />
# 		<meta content="本網站通過第一、第二及第三優先等級無障礙網頁檢測" name="AAAccessible_website" />
# 		<script src="Js/Fyls.js" language="JavaScript"></script>
# 		<noscript>
# 	&lt;/HEAD&gt;
# 	&lt;BODY bgColor="#ffffff" leftMargin="0" topMargin="0"&gt;
# 		您的瀏覽器不支援JavaScript語法,但是並不影響您獲取本網站的內容</noscript>
# 		<script language="JavaScript">
# function openwin(URL,arguments,width,height)
# {
#    //功能:開一個非獨佔的視窗
#    //參數1.URL :連結的網頁
#    //參數2.arguments :傳入網頁的參數
#    /*
#    var str = URL  //+"?"+arguments;
# ...
