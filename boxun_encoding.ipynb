# %%
# -*- coding: utf-8 -*-
__author__ = 'BigData'
import requests,urllib2
from bs4 import BeautifulSoup
requests.packages.urllib3.disable_warnings()
dataform = {'cat':'china','year':'2014','month':'10','date':'all'}
headers ={
    'Accept':'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
    'Accept-Encoding':'gzip, deflate',
    'Cache-Control':'max-age=0',
    'Connection':'keep-alive',
    'Content-Length':'37',
    'Content-Type':'application/x-www-form-urlencoded',
    'Cookie':'__gads=ID=f2d671063f7ad81d:T=1438725394:S=ALNI_MYRLgnV6pI_AV0XmQYGW_JBP5dVgA; __utma=204650115.1892445826.1438725394.1438725394.1438736681.2; __utmc=204650115; __utmz=204650115.1438736681.2.2.utmcsr=google|utmccn=(organic)|utmcmd=organic|utmctr=(not%20provided); _ga=GA1.2.1892445826.1438725394',
    'Host':'www.boxun.com',
    'Origin':'http://www.boxun.com',
    'Referer':'http://www.boxun.com/search.shtml',
    'Upgrade-Insecure-Requests':'1',
    'User-Agent':'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_7_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/44.0.2403.125 Safari/537.36'
}
url = 'http://www.boxun.com/cgi-bin/search/find_by_date.cgi'
res = requests.post(url, data=dataform, headers=headers)
res.encoding='gb2312'
page = res.text
#res_text = res.text.encode('utf-8').prettify()
#request = urllib2.Request(url, data, headers)
#page = urllib2.urlopen(res_text)
#contents = urllib2.urlopen(request).read()
#page = urllib2.urlopen(res)
soup = BeautifulSoup(page)
print soup
#print soup.originalEncoding
#print soup.prettify()
# Out:
# <html><head>
# <title>搜索结果</title>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="no-cache" http-equiv="pragma"/>
# <meta content="博讯，博讯新闻，中国、国际新闻，政治内幕，boxun news, boxun.com, peacehall.com" name="keywords"/>
#
# </head>
#
#
# <body bgcolor="#FFFFFF" leftmargin="5" rightmargin="5" topmargin="5">
# <center>
# <table border="0" cellpadding="0" cellspacing="0" width="800"><tbody><tr><td width="1%">
#     </td><td>
# <table border="0" cellpadding="0" cellspacing="0" width="100%"><tbody><tr><td align="right" valign="bottom">
#   <a href="/aboutus.shtml">
#   <font size="-1">  关于我们       </font> </a>    <font face="Courier New" size="-1"> -      </font>
#   <a href="/register.shtml">  <font size="-1">  加入博讯记者
# 	</font>  </a>   <font face="Courier New" size="-2"> -  </font>
#   	<a href="/member.htm">  <font size="-1">  记者发稿登录 	</font>
#   </a>
#   <font face="Courier New" size="-1"> - 	</font>
# 		<a href="/freezone.shtml">
#   <font size="-1">
#      自由发稿区
# 	</font>
#
#     </a>      </td></tr></tbody></table>
# <hr noshade="" size="1"/>
# </td></tr></tbody></table>
#
# <table border="0" cellpadding="0" cellspacing="0" width="800">
# <tbody><tr valign="top"><td width="20%"><img border="0" height="40" src="/images/logo_40.gif" width="207"/>
#
# </td><td align="center" width="20%">
#
# </td><td width="60%">
#     <p align="center"><b><font color="#800000">想说服对方那就要听他怎么说<br/>不要用任何方式把他赶走！</font></b></p>
# </td></tr>
# <tr><td align="center" colspan="3" height="5" width="798"></td></tr>
# </tbody></table>
#
# <table border="0" cellpadding="2" cellspacing="0" width="800"><tbody><tr>
# <td align="center" bgcolor="#DADAAA" nowrap="">
#
#
#         <a href="/index.shtml"><font color="black" size="2">[主页]</font></a>
#          <a href="/news/gb/china/page1.shtml"><font color="black" size="2">大陆</font></a>
#         <a href="/news/gb/taiwan/page1.shtml"><font color="black" size="2">港澳台</font></a>
#         <a href="/news/gb/intl/page1.shtml"><font color="black" size="2">国际</font></a>
#         <a href="/news/gb/misc/page1.shtml"><font color="black" size="2">社会万象</font></a>
#         <a href="/news/gb/sport_ent/page1.shtml"><font color="black" size="2">体育娱乐</font></a>
#         <a href="/news/gb/pubvp/page1.shtml"><font color="black" size="2">大众观点</font></a>
#         <a href="/news/gb/yuanqing/page1.shtml"><font color="black" size="2">不平则鸣</font></a>
#         <a href="/news/gb/z_special/page1.shtml"><font color="black" size="2">特别刊载</font></a>
#         <a href="http://www.boxun.com/my-cgi/forum/mainpage.cgi"><font color="black" size="2">博讯论坛</font></a>
#         <a href="http://www.boxun.com/my-cgi/ziyou/mainpage.cgi"><font color="black" size="2">人权论坛</font></a>
#            <font color="black" size="2">
#          <a href="/news/gb/english/page1.shtml"><font color="black">[English]</font></a>
#
#         </font>
#
# </td></tr><tr bgcolor="#CC3333"><td>
# <table border="0" cellpadding="0" cellspacing="0">
# <tbody><tr><td height="2"></td></tr></tbody></table></td></tr></tbody></table><font face="Courier New" size="-2"></font><table border="0" cellpadding="0" cellspacing="0" width="800">
#   <tbody>
#   <tr>
#     <td bgcolor="#cccccc" width="1"><font size="-2"><img alt="" border="0" height="15" width="1"/></font></td>
#     <td align="center" bgcolor="#eeeeee" width="798">
#     <span style="FONT-SIZE: 9pt">
#     <!--#exec cgi="/cgi-bin/news/gb_display/print_time.cgi" -->
#     </span>
#     </td>
#     <td bgcolor="#cccccc" width="1"><font size="-2"><img alt="" border="0" height="15" src="/images/dot.gif" width="1"/></font></td>
# 	</tr></tbody>
# </table>
# <table border="0" cellpadding="0" cellspacing="0" width="800">
#   <tbody>
#   <tr>
#     <td bgcolor="#cccccc" width="147"><font size="-2"><img alt="" border="0" height="1" src="/images/dot.gif" width="147"/></font></td>
# 		<td bgcolor="#eeeeee" width="7"><font size="-2"><img alt="" border="0" height="1" src="/images/dot.gif" width="7"/></font></td>
# 		<td bgcolor="#cccccc" width="450"><font size="-2"><img alt="" border="0" height="1" src="/images/dot.gif" width="450"/></font></td>
#   </tr>
#   </tbody>
# </table>
# <table border="0" cellpadding="0" cellspacing="0" width="800">
# <tbody><tr valign="top">
# <td bgcolor="#CCCCCC" width="1">
# <font size="-2">
# <img alt="" height="1" src="/images/dot.gif" width="1"/>
# </font>
# </td>
# <td align="LEFT" valign="TOP" width="560">
# <table><tbody><tr><td>
# <font size="-2"><img alt="" border="0" height="1" src="/images/dot.gif" width="1"/></font>
#
# <h3>查询结果</h3> <font size="2">你知道吗？博讯文坛每日都有精彩文章！
# <a href="http://boxun.com/hero">http://boxun.com/hero</a></font><br/><br/>
# <li> <a href="/news/gb/china/2014/10/201410010004.shtml">在京访民60余人自发相聚公开声援香港占中 <font color="red">(图)</font> </a><br/></li><li> <a href="/news/gb/china/2014/10/201410010016.shtml">美国之音独家视频 江泽民连续在京露面 </a><br/></li><li> <a href="/news/gb/china/2014/10/201410010045.shtml">中国官媒：难定ISIS为恐怖组织 <font color="red">(图)</font> </a><br/></li><li> <a href="/news/gb/china/2014/10/201410010049.shtml">习近平决心把扭曲的社会价值观扭回来 <font color="red">(图)</font> </a><br/></li><li> <a href="/news/gb/china/2014/10/201410010052.shtml">广州市民声援占中多人被抓捕、被饿饭 </a><br/></li><li> <a href="/news/gb/china/2014/10/201410010054.shtml">北京维权人士韩颖、郭桂军皆遭警察敲门欲带走 </a><br/></li><li> <a href="/news/gb/china/2014/10/201410010057.shtml">北京对香港噤声 习近平的隐秘棋局 <font color="red">(图)</font> </a><br/></li><li> <a href="/news/gb/china/2014/10/201410010059.shtml">大庆一肯德基发生砍人事件 12人受伤 <font color="red">(图)</font> </a><br/></li><li> <a href="/news/gb/china/2014/10/201410010100.shtml">身体不如从前？ 江泽民露面需有人搀扶 <font color="red">(图)</font> </a><br/></li><li> <a href="/news/gb/china/2014/10/201410010101.shtml">四中全会时间确定 10月20日召开 </a><br/></li><li> <a href="/news/gb/china/2014/10/201410010102.shtml">江泽民出席国庆招待会 清晰正面照曝光 <font color="red">(图)</font> </a><br/></li><li> <a href="/news/gb/china/2014/10/201410010125.shtml">蓝翔校长拥多地户籍 包括一北京户口 <font color="red">(图)</font> </a><br/></li><li> <a href="/news/gb/china/2014/10/201410010128.shtml">社科院院长重提阶级斗争 招来一片谩骂 </a><br/></li><li> <a href="/news/gb/china/2014/10/201410010129.shtml">胡温是羊习近平是狮子 南方系偃旗息鼓 </a><br/></li><li> <a href="/news/gb/china/2014/10/201410010152.shtml">北京、南通支持香港，拥抱自由！ <font color="red">(图)</font> </a><br/></li><li> <a href="/news/gb/china/2014/10/201410010217.shtml">邯郸警方：“警察目睹醉酒女遭三男轮奸”不实 </a><br/></li><li> <a href="/news/gb/china/2014/10/201410010244.shtml">旧金山华人“人道中国”抗议中共重判伊力哈木 <font color="red">(图)</font> </a><br/></li><li> <a href="/news/gb/china/2014/10/201410010250.shtml">北京维权人士韩颖因香港占中被警察敲门骚扰 <font color="red">(图)</font> </a><br/></li><li> <a href="/news/gb/china/2014/10/201410010252.shtml">香港“占中”引发国际关注 大陆转贴公民遭刑拘 <font color="red">(图)</font> </a><br/></li><li> <a href="/news/gb/china/2014/10/201410010254.shtml">新公民袁冬获释 60公民监狱迎接却扑空 <font color="red">(图)</font> </a><br/></li><li> <a href="/news/gb/china/2014/10/201410010255.shtml">北京韩颖发微信要去香港 遭到警察通宵威胁 </a><br/></li><li> <a href="/news/gb/china/2014/10/201410010257.shtml">湖北江北监狱工厂内服刑男子中毒身亡 <font color="red">(图)</font> </a><br/></li><li> <a href="/news/gb/china/2014/10/201410010259.shtml">宁夏600公交售票员维权被抓打 秦皇岛工人游行讨薪 <font color="red">(图)</font> </a><br/></li><li> <a href="/news/gb/china/2014/10/201410010315.shtml">张思之因血栓住院 莫少平代理高瑜案 </a><br/></li><li> <a href="/news/gb/china/2014/10/201410010321.shtml">中共政治局会议决定18届四中全会日期 <font color="red">(图)</font> </a><br/></li><li> <a href="/news/gb/china/2014/10/201410010322.shtml">伊力哈木辩护律师质疑央视新闻专题片 <font color="red">(图)</font> </a><br/></li><li> <a href="/news/gb/china/2014/10/201410010324.shtml">香港"占中"新闻在中国社交网站仍被控 <font color="red">(图)</font> </a><br/></li><li> <a href="/news/gb/china/2014/10/201410010328.shtml">爱国不爱党：中国官方力挺网上“爱国者” <font color="red">(图)</font> </a><br/></li><li> <a href="/news/gb/china/2014/10/201410010330.shtml">上海自贸区一周年：突破不多 教训难得 <font color="red">(图)</font> </a><br/></li><li> <a href="/news/gb/china/2014/10/201410010441.shtml">桂林维权人士胡宁遭国安局抓捕 </a><br/></li><li> <a href="/news/gb/china/2014/10/201410010452.shtml">上海人权捍卫者陈建芳家庭被骚扰/巴黎动态 </a><br/></li><li> <a href="/news/gb/china/2014/10/201410010453.shtml">国庆夜上海动迁公司打手挑事端 </a><br/></li><li> <a href="/news/gb/china/2014/10/201410010457.shtml">山西补齐13名省委常委 吴政隆任太原市委书记 </a><br/></li><li> <a href="/news/gb/china/2014/10/201410010459.shtml">黑龙江大庆肯德基店发生持刀伤人事件 12人受伤 </a><br/></li><li> <a href="/news/gb/china/2014/10/201410010513.shtml">曾庆红仕途之路 全是受小兄弟们启发 <font color="red">(图)</font> </a><br/></li><li> <a href="/news/gb/china/2014/10/201410010520.shtml">汶川地震还笑 谭力涉受贿通奸被查 <font color="red">(图)</font> </a><br/></li><li> <a href="/news/gb/china/2014/10/201410010521.shtml">习近平内部讲话曝光 句句有骨字字刺 <font color="red">(图)</font> </a> ...
# <img alt="" height="1" src="/images/dot.gif" width="1"/></font>
#
# </td>
# </tr>
# </tbody></table>
# <table border="0" cellpadding="0" cellspacing="0" width="800">
#   <tbody>
#   <tr>
#     <td bgcolor="#cccccc" width="146"><font size="-2"><img alt="" border="0" height="1" src="/images/dot.gif" width="146"/></font></td>
# 		<td bgcolor="#eeeeee" width="7"><font size="-2"><img alt="" border="0" height="1" src="/images/dot.gif" width="7"/></font></td>
# 		<td bgcolor="#cccccc" width="450"><font size="-2"><img alt="" border="0" height="1" src="/images/dot.gif" width="450"/></font></td>
#   </tr>
#   </tbody>
# </table>
#
# <table border="0" cellpadding="0" cellspacing="0" width="800">
#   <tbody>
#   <tr>
#     <td bgcolor="#cccccc" width="1"><font size="-2"><img alt="" border="0" height="15" src="/images/dot.gif" width="1"/></font></td>
#
#     <td bgcolor="#eeeeee" width="798">
#
# <font size="-2">
# </font></td>
#     <td bgcolor="#cccccc" width="1"><font size="-2"><img alt="" border="0" height="15" src="/images/dot.gif" width="1"/></font></td>
# 	</tr></tbody>
# </table>
#
#  <center>
# <table border="0" cellpadding="2" cellspacing="0" width="800"><tbody><tr bgcolor="#CC3333"><td><table border="0" cellpadding="0" cellspacing="0"><tbody><tr><td height="2"></td></tr></tbody></table></td></tr><tr><td colspan="12" width="12"></td></tr></tbody></table>
#
# </center>
#
# <table bgcolor="#FFFFFF" border="0" cellpadding="0" cellspacing="0" width="800">
# <tbody><tr><td>
#
#    <hr/>
#    <p align="center">
#       <em>
#       <font face="Courier New" size="-2">All rights reserved <br/></font></em>	<em>
#       <font size="-2">博讯是畅所欲言的场所、所有文章均不一定代表博讯立场</font></em>
#
#    </p>
#
#   </td></tr>
# </tbody></table>
#
#
#
# </center></body></html>

# %%
# -*- coding: utf-8 -*-
__author__ = 'BigData'
import requests
from bs4 import BeautifulSoup
