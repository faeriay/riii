# %%
import requests
from bs4 import BeautifulSoup
res = requests.get('http://www.appledaily.com.tw/realtimenews/section/new/')
soup = BeautifulSoup(res.text)
for ele in soup.select('#maincontent a'):
    if len(ele.select('font')) > 0:
        if '王金平'.decode('utf-8') in ele.select('font')[0].text :
            print ele.select('font')[0].text
# Out:
# 談公道伯粉專　王金平：儘量回應鄉民(0)

# %%
import pandas as pd
df = pd.DataFrame(ary)
df.sort(['count'], ascending=False).head()
# Out:
#       count                    title
# 248  518753  【更新】屁孩ＧＧ了！一次撞兩台　名車＋跑...
# 497  394928      【更新】惡房東張淑晶又告人　這回踢鐵板
# 502  270232       【獨家】2賤狼撿屍　載到凶案現場性侵
# 449  268708      結婚前六天　才知婚禮場地「兩個新娘」！
# 540  183594          鯉魚刺得不像　少年父怒告刺青師

# %%
import requests
from bs4 import BeautifulSoup
import re
ary = []
for i in range(1,20):
    res = requests.get('http://www.appledaily.com.tw/realtimenews/section/new/%d'%(i))
    soup = BeautifulSoup(res.text)
    for ele in soup.select('#maincontent a'):
        if len(ele.select('font')) > 0:
            m = re.match('(.*)\((\d+)\)', ele.select('font')[0].text)
            if m:
                ary.append({'title':m.group(1), 'count':int(m.group(2))})

# %%
import requests
from bs4 import BeautifulSoup
import re
ary = []
ind  = []
res = requests.get('http://www.appledaily.com.tw/realtimenews/section/new/1')
soup = BeautifulSoup(res.text)
for ele in soup.select('.rtddt'):
    if len(ele.select('font')) > 0:
        ind.append(ele.select('a')[0]['href'])
        ary.append(ele.select('font')[0].text)

# %%
class Person():
    count = 0 # Static/class variable
    def __init__(self, name, city):
        self.name = name # Variable for the instance
        self.city = city # Variable for the instance
        Person.count += 1
    def number_of_persons(self):
        return Person.count

# %%
first = Person("David", "Chiayi")
print first.number_of_persons()
# Out:
# 1

# %%
second = Person("Qoo", "Taipei")
print second.number_of_persons()
# Out:
# 2

# %%
class MyInteger():
    def __init__(self, integer):
        print "constructor"
        self.integer = integer
    def __add__(self, integer): # Overloaded '+' operator
        if self.integer == 2 and integer == 2:
            return 5
        else:
            return self.integer + integer

# %%
a = MyInteger(2)
# Out:
# constructor

# %%
a+1
# Out:
# 3

# %%
a+2
# Out:
# 5

# %%
import operator
sorted_x = sorted(dic.items(), key=operator.itemgetter(1), reverse=True)
print sorted_x[0:50]
# Out:
# [('the', 105), ('of', 53), ('in', 39), ('and', 38), ('a', 37), ('Louisiana', 33), ('7', 32), ('shooting', 32), ('theater', 28), ('Police', 26), ('The', 26), ('Lafayette,', 21), ('at', 21), ('to', 20), ('was', 17), ('Lafayette', 16), ('Hide', 15), ('Movie', 15), ('Caption', 15), ('photos', 15), ('an', 15), ('near', 14), ('State', 12), ('shooting.', 12), ('said', 12), ('scene', 11), ('said.', 11), ('Department', 10), ('entrance', 10), ('Grand', 10), ('with', 10), ('he', 10), ('movie', 9), ('is', 9), ('scene.', 8), ('on', 8), ('lafayette', 7), ('road', 6), ('Gov.', 6), ('block', 6), ('that', 6), ('shooter', 6), ('his', 6), ('she', 6), ('it', 6), ('units', 6), ('just', 6), ('night', 6), ('Jindal,', 6), ('Police.', 6)]

# %%
help(sorted)
# Out:
# Help on built-in function sorted in module __builtin__:
#
# sorted(...)
#     sorted(iterable, cmp=None, key=None, reverse=False) --> new sorted list

# %%
help(requests.post)
# Out:
# Help on function post in module requests.api:
#
# post(url, data=None, json=None, **kwargs)
#     Sends a POST request.
#
#     :param url: URL for the new :class:`Request` object.
#     :param data: (optional) Dictionary, bytes, or file-like object to send in the body of the :class:`Request`.
#     :param json: (optional) json data to send in the body of the :class:`Request`.
#     :param \*\*kwargs: Optional arguments that ``request`` takes.
#     :return: :class:`Response <Response>` object
#     :rtype: requests.Response

# %%
import requests
from bs4 import BeautifulSoup
for pg in range(0,2):
    res = requests.get('https://www.iyp.com.tw/search.php?a_id=&k=%E8%8B%B1%E6%96%87+%E8%A3%9C%E7%BF%92%E7%8F%AD&p={0}'.format(pg))
    #print res.encoding
    res.encoding = 'utf-8'

    soup = BeautifulSoup(res.text)
    for ele in soup.select('.general li'):
        if len(ele.select('h3')) > 0:
            print ele.select('h3')[0].text, \
                  ele.select('.view-map')[0]['go-map'].split('&k=')[1], \
                  ele.select('a')[0]['href'].split('www.iyp.com.tw/')[1].split('/')[0]
# Out:
# 高鼎英文補習班 台南市新營區綠川北街65號 066376381
# 許鎮高中英文補習班 台東縣台東市寧波街6號 089353305
# 李捷英文補習班 新北市三重區力行路二段182號2樓 0222879393
# 杜老師英文補習班 台北市莊敬路300號2樓 0287874282
# 沈老師英文補習班 台北市昆明街121號2樓 0223822292
# 琴森英文補習班 台北市內湖路一段309號1樓及地下1樓 0227988342
# 碧老師英文補習班 台北市北安路630巷25弄9號1樓 0225338812
# 嘉義市私立黃氏英語國語正音短期職業補習班 嘉義市民族路874號 052332776
# 私立Ｅ－Ｚ語文短期補習班 南投縣埔里鎮民生路77號 0492990082
# 私立立進電腦美語文理短期補習班 桃園市桃園區同安街550號 033570003
# 私立立進電腦美語文理短期補習班 桃園市桃園區同安街550號1至3樓 033586817
# 私立薇薇安美語補習班 高雄市左營區華夏路979號 073415000
# 嘉義市私立學思園文理短期補習班 嘉義市南京路398號3樓 052368766
# 臺北市私立北一文理短期補習班 台北市中正區信義路二段271號5樓 0223936666
# 臺北市私立北一文理短期補習班 台北市中正區南陽街14號 0223149450
# 台北市私立北一文理短期補習班 台北市大安區信義路三段7號1樓 0227007125-1
# 台北市私立北一文理短期補習班 台北市中正區南陽街14號 0223146727
# 私立嘉耘文理短期補習班 高雄市左營區文恩路26號1之3樓 073496700
# 雲林縣私立吳爾夫英文文理短期補習班 雲林縣虎尾鎮大成街301號 056311555-1
# 雲林縣私立世界文理美語短期補習班 雲林縣斗六市雲林路一段180巷9號 055329149-2

# %%
bid_file = open("bid_list.txt", 'w')
page_format ="http://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=advance&searchTarget=ATM&method=search&isSpdt=&pageIndex=%d"
for page in range(1, page_number + 1):
    bid_list = rs.get(page_format%(page))
    bid_response = bid_list.text.encode('utf8')
    bid_soup = BeautifulSoup(bid_response)
    bid_table = bid_soup.select("#print_area") [0]
    bid_rows = bid_table.select('tr')[1:-1]
    for bid_row in bid_rows:
        link_href = "http://web.pcc.gov.tw/tps" +bid_row.select('a')[0]['href'][2:]
        bid_file.write(link_href + "\n")
bid_file.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-497936beca66> in <module>()
#       1 bid_file = open("bid_list.txt", 'w')
#       2 page_format ="http://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=advance&searchTarget=ATM&method=search&isSpdt=&pageIndex=%d"
# ----> 3 for page in range(1, page_number + 1):
#       4     bid_list = rs.get(page_format%(page))
#       5     bid_response = bid_list.text.encode('utf8')
#
# NameError: name 'page_number' is not defined

# %%
import requests
payload = { 'method':'search', 'searchMethod':'true', 'searchTarget':'ATM',
'orgName':'', 'orgId':'', 'hid_1':'1',
'tenderName':'', 'tenderId':'', 'tenderStatus':'4,5,21,29',
'tenderWay':'', 'awardAnnounceStartDate':'104/07/24',
'awardAnnounceEndDate':'104/07/24', 'radProctrgCate':'3',
'proctrgCate':'3', 'tenderRange':'', 'minBudget':'',
'maxBudget':'', 'item':'','hid_2':'1',
'gottenVendorName':'', 'gottenVendorId':'', 'hid_3':'1',
'submitVendorName':'', 'submitVendorId':'', 'location':'',
'priorityCate':'', 'isReConstruct':'', 'btnQuery':'查詢' }

# %%
user_post = requests.post("http://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=advance", data=payload)
response_text = user_post.text.encode('utf8')

# %%
user_post =requests.post("http://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=advance", data=payload)
response_text = user_post.text.encode('utf8')
soup = BeautifulSoup(response_text)
print soup.select('.T11b')
print soup.select('.T11b')[0]
print soup.select('.T11b')[0].text
# Out:
# [<span class="T11b" style="color: red;">214</span>]
# <span class="T11b" style="color: red;">214</span>
# 214

# %%
rec_number_element = soup.select('.T11b')[0]
rec_number = int(rec_number_element.text)
print rec_number
# Out:
# 214

# %%
import math
page_number = int(math.ceil(float(rec_number) / 100))
print page_number
# Out:
# 3

# %%
bid_file = open("bid_list.txt", 'w')
page_format ="http://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=advance&searchTarget=ATM&method=search&isSpdt=&pageIndex=%d"
for page in range(1, page_number + 1):
    bid_list = rs.get(page_format%(page))
    bid_response = bid_list.text.encode('utf8')
    bid_soup = BeautifulSoup(bid_response)
    bid_table = bid_soup.select("#print_area") [0]
    bid_rows = bid_table.select('tr')[1:-1]
    for bid_row in bid_rows:
        link_href = "http://web.pcc.gov.tw/tps" +bid_row.select('a')[0]['href'][2:]
        bid_file.write(link_href + "\n")
bid_file.close()

# %%
rs = requests.session()
print type(rs)
rs_post =rs.post("http://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=advance", data=payload)
rs_get =rs.get("http://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=advance&searchTarget=ATM&method=search&isSpdt=&pageIndex=2")
response = rs_get.text.encode('utf8')
# Out:
# <class 'requests.sessions.Session'>

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(res.text)
print soup.select('#printArea')[0]
# Out:
# <div class="main" id="printArea">
#
#               	﻿﻿﻿﻿﻿<!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN">
#
# <head>
# <link href="/tps/styles/text.css" rel="stylesheet" type="text/css"/>
# <link href="/tps/styles/css.css" rel="stylesheet" type="text/css"/>
# <link href="/tps/styles/chtd_tab.css" rel="stylesheet" type="text/css"/>
# <link href="/tps/styles/chtd.css" rel="stylesheet" type="text/css"/>
# <style>
# td {align: left;}
# </style>
# </head>
# <script>
# $jq(document).ready(function(){
# 	popWatermark();
# });
#
# function openEditScreen(editUrl){
#     window.open(encodeURI(editUrl));
#     unblock();
# }
#
# function popWatermark(){
# 	        var msgTop = 50;
# 	        var msgLeft = 500;
#
# 	        try{
# 	        	msgTop = $jq("#printArea").position().top+50;
# 	        	msgLeft = $jq("#printArea").position().left +$jq("#printArea").width()/2 +50;
# 			}catch(e) {}
#
# 			$jq("#hidden_message_id")
# 	        .css({
# 	            fontSize: "100px", //watermark font size
# 	            color: "brown", //watermark color
# 	            fontWeight: "bolder", //watermark font weight
# 	            fontFamily: "verdana", //watermark font family
# 	            position: "absolute", //watermark position 必須為 "absolute"
# 	            width: "100px", //watermark div width
# 	            top: msgTop, //watermark position top
# 	            left: msgLeft //watermark position left
# 	        })
# 	        .fadeTo("fast",0.3); //watermark 透明度
# }
#
# function popWatermark2(){
# 	        var msgTop = 200;
# 	        var msgLeft = 500;
# 			$jq("#hidden_message_id")
# 	        .css({
# 	            fontSize: "120px", //watermark font size
# 	            color: "brown", //watermark color
# 	            fontWeight: "bolder", //watermark font weight
# 	            fontFamily: "verdana", //watermark font family
# 	            position: "absolute", //watermark position 必須為 "absolute"
# 	            width: "120px", //watermark div width
# 	            top: msgTop, //watermark position top
# 	            left: msgLeft //watermark position left
# 	        })
# 	        .fadeTo("fast",0.3); //watermark 透明度
# }
#
# //共同供應契約顯示得標廠商清單
# function printBidder(pkItem){
# 		//alert(pkItem);
#
# 		    var popupWindow = window.open('/tps/main/pms/tps/atm/atmAwardAction.do?method=qryCppObtain&pkAtmMain=51603189&pkAtmAwardItem='+pkItem+'&tenderCaseNo=1040202','showBidder','status=yes,toolbar=no,menubar=no,location=no,resizable=yes,scrollbars=yes,width=750,height=500',true);
#
# }
# </script>
# <table border="1" cellpadding="0" cellspacing="0" class="table_block tender_table" width="100%">
# <caption style="display:none">
# <center><font size="5">更正決標公告</font></center>
# <div align="center" id="printAwardDate" style="display:block">公告日:104/07/28</div>
# </caption>
# <tbody>
# <tr>
# <td align="center" colspan="4" style="border:1px solid #FFFFFF;">
# <center><h1>更正決標公告</h1></center>
# <div align="center" id="printAwardDate" style="display:block"><h3>公告日:104/07/28</h3></div>
# <div class="remind_msg"></div>
# </td>
# </tr>
# <tr class="award_table_tr_1" id="noneDisWord">
# <td align="left" class="T12" colspan="4">註：<font color="red"><strong>◎</strong></font>紅色字體表示此次更正公告與前次之差異，前次公告內容於滑鼠移至文字上方時自動顯示</td>
# </tr>
# <!-- delimiter 機關資料 Start -->
# <tr class="award_table_tr_1">
# <td align="center" bgcolor="#89C0C7" class="style1" rowspan="8" valign="middle" width="38">
# <span class="newstop">機<br/>關<br/>資<br/>料</span>
# </td>
# </tr>
# <tr class="award_table_tr_1">
# <th align="left" bgcolor="#DAEBED" class="T11b" valign="middle" width="200">機關代碼</th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
# 			3.13.2
# 		</td>
# </tr>
# <tr class="award_table_tr_1">
# <th align="left" bgcolor="#DAEBED" class="T11b" valign="middle" width="200">機關名稱</th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
# 			經濟部工業局
# 		</td>
# </tr>
# <tr class="award_table_tr_1">
# <th align="left" bgcolor="#DAEBED" class="T11b" valign="middle" width="200">單位名稱</th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
#             電子資訊組
#         </td>
# </tr>
# <tr class="award_table_tr_1">
# <th align="left" bgcolor="#DAEBED" class="T11b" valign="middle" width="200">機關地址</th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
#
#
#
#
#
#
#
#
#
#
#                               110臺北市信義區信義路路三段41-3號
# 		</td>
# </tr>
# <tr class="award_table_tr_1">
# <th align="left" bgcolor="#DAEBED" class="T11b" valign="middle" width="200">聯絡人</th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
#
#
# 			軟體採購辦公室
# 	</td>
# </tr>
# <tr class="award_table_tr_1">
# <th align="left" bgcolor="#DAEBED" class="T11b" valign="middle" width="200">聯絡電話</th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
#
#
#
#
#                               (02)66072558
#                           </td>
# </tr>
# <tr class="award_table_tr_1">
# <th align="left" bgcolor="#DAEBED" class="T11b" style="height: 25px" valign="middle" width="200">傳真號碼</th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
#
#
#
#
#                               (02)66006717
#                           </td>
# </tr>
# <!-- delimiter 機關資料 End -->
# <!-- delimiter 已公告/採購資料 Start -->
# <tr class="award_table_tr_2">
# <td align="center" bgcolor="#FCD847" class="form_head" rowspan="30 " valign="middle" width="38">
# <span class="newstop">已<br/>公<br/>告<br/>資<br/>料</span>
# </td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">標案案號</th>
# <td bgcolor="#EFF1F1" class="newstop">
# 			1040202
# 		</td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">招標方式</th>
# <td bgcolor="#EFF1F1" class="newstop">
# 			限制性招標(經公開評選或公開徵求)
# 			<div class="remind_msg">
# </div>
# </td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">決標方式</th>
# <td bgcolor="#EFF1F1" class="newstop">
# 			準用最有利標
# 			<div class="remind_msg">
# </div>
# </td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">新增公告傳輸次數</th>
# <td bgcolor="#EFF1F1" class="newstop">
# 			01
# 		</td>
# </tr>
# <tr class="award_table_tr_2">
# <th bgcolor="#FFFF99" class="T11b" width="200">公告更正序號</th>
# <td bgcolor="#EFF1F1" class="newstop">
# 			01
# 		</td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">是否依據採購法第106條第1項第1款辦理</th>
# <td bgcolor="#EFF1F1" class="newstop">
#
# 			否
#         </td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">標案名稱</th>
# <td bgcolor="#EFF1F1" class="newstop">
#
#
# 			104年第二次電腦軟體共同供應契約採購－雲端服務
# 		</td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">決標資料類別</th>
# <td bgcolor="#EFF1F1" class="newstop">
# 			決標公告
# 		</td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">是否屬共同供應契約採購</th>
# <td bgcolor="#EFF1F1" class="newstop">
#
#
#
#
#
#
#
#
#
#
# 			是
#
# 		</td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">是否屬二以上機關之聯合採購(不適用共同供應契約規定)</th>
# <td bgcolor="#EFF1F1" class="newstop">
# 			否
#
# 		</td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">是否複數決標</th>
# <td bgcolor="#EFF1F1" class="newstop">
#
#
#
#
#
#
#
#
#
#
# 			是
#
# 		</td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">標的分類</th>
# <td bgcolor="#EFF1F1" class="newstop">
#
#
#
#
#
#
#
#
#
#
#
#
# 							&lt;勞務類&gt;
#                             842
#                             軟體執行服務
#
# 		</td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">是否屬統包</th>
# <td bgcolor="#EFF1F1" class="newstop">
#
#
#
#
#
#
#
#
#
#
#         	否
#          </td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">是否應依公共工程專業技師簽證規則實施技師簽證</th>
# <td bgcolor="#EFF1F1" class="newstop">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         	否
#
#         </td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">開標時間</th>
# <td bgcolor="#EFF1F1" class="newstop">
#         	104/05/19 09:30
#         </td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">原公告日期</th>
# <td bgcolor="#EFF1F1" class="newstop">
#         	104/04/27
#         </td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">採購金額級距</th>
# <td bgcolor="#EFF1F1" class="newstop">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         	巨額
# 			<div class="remind_msg">
# </div>
# </td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">辦理方式</th>
# <td bgcolor="#EFF1F1" class="newstop">
#
#
#
#
#
#
#
#
#
#
#
#
# 			自辦
# 		</td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">限制性招標<br>依據之法條</br></th>
# <td bgcolor="#EFF1F1" class="newstop">
# 	    	採購法第22條第1項第9款
#
#
#
#
#
# 	    </td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">是否適用條約或<br>協定之採購</br></th>
# <td bgcolor="#EFF1F1" class="newstop">
# <style type="text/css">
# 	.gpa_shift {
# 		margin-left: 30px;
# 	}
# 	.gpa_shift2 {
# 		margin-left: 60px;
# 	}
# 	.gpa_error_msg {
# 		color:#FF0000;
# 		font-size:10pt;
# 	}
# </style>
# <strong>是否適用WTO政府採購協定(GPA)：</strong>
#
# 		是
#
#
#
#
#
# 	<hr>
# <strong>是否適用臺紐經濟合作協定(ANZTEC)：</strong>
#
# 		是
#
#
#
#
#
# 	<hr>
# <strong>是否適用臺星經濟夥伴協定(ASTEP)：</strong>
#
# 		是
#
#
#
#
#
#
#
# 		</hr></hr></td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">預算金額是否公開</th>
# <td bgcolor="#EFF1F1" class="newstop">
#
#
#
#
#
#
#
#
#
#
# 			是
#
# 		</td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">預算金額</th>
# <td bgcolor="#EFF1F1" class="newstop">
# 			1,663,050,791元
#
#
#
#
#
#
#
#
#                     </td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">是否受機關補助</th>
# <td bgcolor="#EFF1F1" class="newstop">
#
#
#
#
#
#
#
#
#
#
# 			否
# 		</td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">履約地點</th>
# <td bgcolor="#EFF1F1" class="newstop">
# 			 其他
#                           </td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">履約地點（含地區）</th>
# <td bgcolor="#EFF1F1" class="newstop">
# 	    	臺北市－全區,基隆市－全區,新北市－全區,宜蘭縣－全區,新竹市,新竹縣－全區,桃園市－全區,苗栗縣－全區,臺中市－全區,彰化縣－全區,南投縣－全區,嘉義市,嘉義縣－全區,雲林縣－全區,臺南市－全區,高雄市－全區,屏東縣－全區,臺東縣－全區,花蓮縣－全區,金門縣－全區,澎湖縣－全區,連江縣－全區,其他－其他
# 	         </td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">是否屬優先採購身心障礙福利機構產品或勞務</th>
# <td bgcolor="#EFF1F1" class="newstop">
#
#
#
#
#
#
#
#
#
#
# 			否
# 			</td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">是否含特別預算</th>
# <td bgcolor="#EFF1F1" class="newstop">
#                               否
#
#
#
# 		</td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">歸屬計畫類別</th>
# <td bgcolor="#EFF1F1" class="newstop">
# 			非屬愛台十二項計畫
# 		</td>
# </tr>
# <tr class="award_table_tr_2">
# <th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">本案採購契約是否採用主管機關訂定之範本</th>
# <td bgcolor="#EFF1F1" class="newstop">
# 			是
#
# 		</td>
# </tr>
# <!-- 不公開於其他機關、廠商端、民眾端及政府採購公報電子版 -->
# <!-- 政府計畫管理資訊網之標案案號有值才顯示，但不公開於廠商端/民眾端及政府採購公報 -->
# <!-- delimiter 已公告/採購資料 End -->
# <!-- delimiter 資訊服務價格 Start -->
# <!-- delimiter 資訊服務價格 End -->
# <!-- delimiter 投標廠商 Start -->
# <tr class="award_table_tr_3">
# <td align="center" bgcolor="#F5BF65" rowspan="3" valign="middle" width="38">
# <span class="newstop">投<br/>標<br/>廠<br/>商</span>
# </td>
# </tr>
# <tr class="award_table_tr_3">
# <th align="left" bgcolor="#FFDD83" class="T11b" valign="middle" width="200">投標廠商家數</th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
# 			8
# 		</td>
# </tr>
# <tr class="award_table_tr_3">
# <th align="left" bgcolor="#FFDD83" class="T11b" valign="top" width="200">投標廠商</th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
# 		請使用"顯示完整資料"察看詳細資料。
# 		</td>
# </tr>
# <!-- delimiter 投標廠商 End -->
# <!-- delimiter 簽約廠商 Start -->
# <!-- delimiter 簽約廠商 End -->
# <!-- delimiter 決標品項 Start -->
# <tr class="award_table_tr_4">
# <td align="center" bgcolor="#FF9999" rowspan="3" valign="middle" width="38">
# <span class="newstop">決<br/>標<br/>品<br/>項</span>
# </td>
# </tr>
# <tr class="award_table_tr_4">
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">決標品項數</th>
# <td bgcolor="#EFF1F1" class="newstop">
# 				156
# 			</td>
# </tr>
# <tr class="award_table_tr_4">
# <th align="left" bgcolor="#FFCCCC" class="T11b" valign="middle" width="200">決標品項</th>
# <td bgcolor="#EFF1F1" class="newstop">
# 				請使用"顯示完整資料"察看詳細資料。</td>
# </tr>
# <!-- delimiter 決標品項 End -->
# <!-- delimiter 最有利標 Start -->
# <script src="/tps/scripts/js/jquery.validate.min.js" type="text/javascript"></script>
# <script src="/tps/scripts/js/jquery.metadata.min.js" type="text/javascript"></script>
# <link href="/tps/styles/templet.css" rel="stylesheet" type="text/css">
# <link href="/tps/styles/mat.css" rel="stylesheet" type="text/css">
# <tr class="award_table_tr_4_1">
# <td align="center" bgcolor="#ff8888" height="25" rowspan="2" style="width:31px" valign="middle" width="25">
# <span class="newstop">
#
#
#
#
#
# 									最<br>有<br>利<br>標
#
#
# 					</br></br></br></span>
# </td>
# </tr>
# <tr class="award_table_tr_4_1">
# <th align="left" class="form_head mat_head">
# 			評選委員
#     	</th>
# <td class="form_txt mat_text" id="mat_venderArguTd">
# <table class="main_table_bgPink result_table mat_textColor" summary="*">
# <tr>
# <th>項次</th>
# <th>出席會議</th>
# <th>姓名</th>
# <th>職業</th>
# </tr>
# <tr>
# <td class="mat_textAlignCenter">
# 	    					1
# 	    				</td>
# <td class="mat_textAlignCenter">
#
#
#
#
#
#
#
#
#
#
#
# 	    					 是
# 	    				</td>
# <td class="mat_textAlignCenter">
#
#
# 	    						張正憲
# 	    				</td>
# <td class="mat_textAlignCenter">
#
# 	    					科長
# 	    				</td>
# </tr>
# <tr>
# <td class="mat_textAlignCenter">
# 	    					2
# 	    				</td>
# <td class="mat_textAlignCenter">
#
#
#
#
#
#
#
#
#
#
#
# 	    					 是
# 	    				</td>
# <td class="mat_textAlignCenter">
#
#
# 	    						謝戎峰
# 	    				</td>
# <td class="mat_textAlignCenter">
#
# 	    					副組長
# 	    				</td>
# </tr>
# <tr>
# <td class="mat_textAlignCenter">
# 	    					3
# 	    				</td>
# <td class="mat_textAlignCenter">
#
#
#
#
#
#
#
#
#
#
#
# 	    					 是
# 	    				</td>
# <td class="mat_textAlignCenter">
#
#
# 	    						楊志清
# 	    				</td>
# <td class="mat_textAlignCenter">
#
# 	    					組長
# 	    				</td>
# </tr>
# <tr>
# <td class="mat_textAlignCenter">
# 	    					4
# 	    				</td>
# <td class="mat_textAlignCenter">
#
#
#
#
#
#
#
#
#
#
#
# 	    					 是
# 	    				</td>
# <td class="mat_textAlignCenter">
#
#
# 	    						林根煌
# 	    				</td>
# <td class="mat_textAlignCenter">
#
# 	    					教授
# 	    				</td>
# </tr>
# <tr>
# <td class="mat_textAlignCenter">
# 	    					5
# 	    				</td>
# <td class="mat_textAlignCenter">
#
#
#
#
#
#
#
#
#
#
#
# 	    					 是
# 	    				</td>
# <td class="mat_textAlignCenter">
#
#
# 	    						黃彥男
# 	    				</td>
# <td class="mat_textAlignCenter">
# <span style="color:red;font-weight:bold" title="前次公告為：副執行秘書長">副執行秘書長 </span>
# </td>
# </tr>
# <tr>
# <td class="mat_textAlignCenter">
# 	    					6
# 	    				</td>
# <td class="mat_textAlignCenter">
#
#
#
#
#
#
#
#
#
#
#
# 	    					 是
# 	    				</td>
# <td class="mat_textAlignCenter">
#
#
# 	    						陳泉錫
# 	    				</td>
# <td class="mat_textAlignCenter">
#
# 	    					法務部處長
# 	    				</td>
# </tr>
# <tr>
# <td class="mat_textAlignCenter">
# 	    					7
# 	    				</td>
# <td class="mat_textAlignCenter">
#
#
#
#
#
#
#
#
#
#
#
# 	    					 是
# 	    				</td>
# <td class="mat_textAlignCenter">
#
#
# 	    						馬正維
# 	    				</td>
# <td class="mat_textAlignCenter">
#
# 	    					經濟部主任
# 	    				</td>
# </tr>
# </table>
# </td>
# </tr>
# <!-- delimiter 最有利標 End -->
# <!-- delimiter 英文公告 Start -->
# <tr class="award_table_tr_5">
# <td align="center" bgcolor="99CCCC" rowspan="40" valign="middle" width="38">
# <span class="newstop">英<br/>文<br/>公<br/>告</span>
# </td>
# </tr>
# <tr class="award_table_tr_5">
# <th align="left" bgcolor="#DFDEE6" class="T11b" height="25" valign="middle" width="200">機關名稱</th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
# 			Industrial Development Bureau ministry of  economic affairs
# 		</td>
# </tr>
# <tr class="award_table_tr_5">
# <th align="left" bgcolor="#DFDEE6" class="T11b" height="25" valign="middle" width="200">機關地址</th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
# 			41-3,Sinyi Road Sec.3.Taipei Taiwan ROC
# 		</td>
# </tr>
# <tr class="award_table_tr_5">
# <th align="left" bgcolor="#DFDEE6" class="T11b" height="25" valign="middle" width="200">標案名稱</th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
# 			014 Computer Software Inter-Entity Supply Contracts - Cloud Computing Service
# 		</td>
# </tr>
# <tr class="award_table_tr_5">
# <th align="left" bgcolor="#DFDEE6" class="T11b" height="25" valign="middle" width="200">聯絡人</th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
# 			WANG,YU-JING
# 		</td>
# </tr>
# <tr class="award_table_tr_5">
# <th align="left" bgcolor="#dfdee6" class="T11b" height="7" valign="middle" width="200">聯絡電話</th>
# <td bgcolor="#EFF1F1" class="newstop" height="7">
#
#
# 		886-2-66072558
# 		</td>
# </tr>
# <tr class="award_table_tr_5">
# <th align="left" bgcolor="#dfdee6" class="T11b" height="6" valign="middle" width="200">傳真號碼</th>
# <td bgcolor="#EFF1F1" class="newstop" height="6">
#
#
# 			886-02-66006717
# 		</td>
# </tr>
# <tr class="award_table_tr_5">
# <th align="left" bgcolor="#DFDEE6" class="T11b" valign="middle">
# 			得標廠商<font size="3">1</font>
# </th>
# <td bgcolor="#EFF1F1" class="newstop" height="25"> </td>
# </tr>
# <tr class="award_table_tr_5">
# <th align="left" bgcolor="#DFDEE6" class="T11b" height="25" valign="middle" width="200">廠商代碼</th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
#
#
#
#
# 						12261768
#
#
#
# 		</td>
# </tr>
# <tr class="award_table_tr_5">
# <th align="left" bgcolor="#DFDEE6" class="T11b" height="25" valign="middle" width="200">廠商名稱</th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
# </td>
# </tr>
# <tr class="award_table_tr_5">
# <th align="left" bgcolor="#DFDEE6" class="T11b" height="25" valign="middle" width="200">廠商地址</th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
# </td>
# </tr>
# <tr class="award_table_tr_5">
# <th align="left" bgcolor="#DFDEE6" class="T11b" valign="middle">
# 			得標廠商<font size="3">2</font>
# </th>
# <td bgcolor="#EFF1F1" class="newstop" height="25"> </td>
# </tr>
# <tr class="award_table_tr_5">
# <th align="left" bgcolor="#DFDEE6" class="T11b" height="25" valign="middle" width="200">廠商代碼</th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
#
#
#
#
# 						16300572
#
#
#
# 		</td>
# </tr>
# <tr class="award_table_tr_5">
# <th align="left" bgcolor="#DFDEE6" class="T11b" height="25" valign="middle" width="200">廠商名稱</th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
# </td>
# </tr>
# <tr class="award_table_tr_5">
# <th align="left" bgcolor="#DFDEE6" class="T11b" height="25" valign="middle" width="200">廠商地址</th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
# </td>
# </tr>
# <tr class="award_table_tr_5">
# <th align="left" bgcolor="#DFDEE6" class="T11b" valign="middle">
# 			得標廠商<font size="3">3</font>
# </th>
# <td bgcolor="#EFF1F1" class="newstop" height="25"> </td>
# </tr>
# <tr class="award_table_tr_5">
# <th align="left" bgcolor="#DFDEE6" class="T11b" height="25" valign="middle" width="200">廠商代碼</th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
#
#
#
#
# 						96979997
#
#
#
# 		</td>
# </tr>
# <tr class="award_table_tr_5">
# <th align="left" bgcolor="#DFDEE6" class="T11b" height="25" valign="middle" width="200">廠商名稱</th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
# </td>
# </tr>
# <tr class="award_table_tr_5">
# <th align="left" bgcolor="#DFDEE6" class="T11b" height="25" valign="middle" width="200">廠商地址</th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
# </td>
# </tr>
# <tr class="award_table_tr_5">
# <th align="left" bgcolor="#DFDEE6" class="T11b" valign="middle">
# 			得標廠商<font size="3">4</font>
# </th>
# <td bgcolor="#EFF1F1" class="newstop" height="25"> </td>
# </tr>
# <tr class="award_table_tr_5">
# <th align="left" bgcolor="#DFDEE6" class="T11b" height="25" valign="middle" width="200">廠商代碼</th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
#
#
#
#
# 						16541333
#
#
#
# 		</td>
# </tr>
# <tr class="award_table_tr_5">
# <th align="left" bgcolor="#DFDEE6" class="T11b" height="25" valign="middle" width="200">廠商名稱</th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
# </td>
# </tr>
# <tr class="award_table_tr_5">
# <th align="left" bgcolor="#DFDEE6" class="T11b" height="25" valign="middle" width="200">廠商地址</th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
# </td>
# </tr>
# <tr class="award_table_tr_5">
# <th align="left" bgcolor="#DFDEE6" class="T11b" valign="middle">
# 			得標廠商<font size="3">5</font>
# </th>
# <td bgcolor="#EFF1F1" class="newstop" height="25"> </td>
# </tr>
# <tr class="award_table_tr_5">
# <th align="left" bgcolor="#DFDEE6" class="T11b" height="25" valign="middle" width="200">廠商代碼</th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
#
#
#
#
# 						53756510
#
#
#
# 		</td>
# </tr>
# <tr class="award_table_tr_5">
# <th align="left" bgcolor="#DFDEE6" class="T11b" height="25" valign="middle" width="200">廠商名稱</th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
# </td>
# </tr>
# <tr class="award_table_tr_5">
# <th align="left" bgcolor="#DFDEE6" class="T11b" height="25" valign="middle" width="200">廠商地址</th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
# </td>
# </tr>
# <tr class="award_table_tr_5">
# <th align="left" bgcolor="#DFDEE6" class="T11b" valign="middle">
# 			得標廠商<font size="3">6</font>
# </th>
# <td bgcolor="#EFF1F1" class="newstop" height="25"> </td>
# </tr>
# <tr class="award_table_tr_5">
# <th align="left" bgcolor="#DFDEE6" class="T11b" height="25" valign="middle" width="200">廠商代碼</th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
#
#
#
#
# 						70538068
#
#
#
# 		</td>
# </tr>
# <tr class="award_table_tr_5">
# <th align="left" bgcolor="#DFDEE6" class="T11b" height="25" valign="middle" width="200">廠商名稱</th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
# </td>
# </tr>
# <tr class="award_table_tr_5">
# <th align="left" bgcolor="#DFDEE6" class="T11b" height="25" valign="middle" width="200">廠商地址</th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
# </td>
# </tr>
# <tr class="award_table_tr_5">
# <th align="left" bgcolor="#DFDEE6" class="T11b" valign="middle">
# 			得標廠商<font size="3">7</font>
# </th>
# <td bgcolor="#EFF1F1" class="newstop" height="25"> </td>
# </tr>
# <tr class="award_table_tr_5">
# <th align="left" bgcolor="#DFDEE6" class="T11b" height="25" valign="middle" width="200">廠商代碼</th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
#
#
#
#
# 						70565450
#
#
#
# 		</td>
# </tr>
# <tr class="award_table_tr_5">
# <th align="left" bgcolor="#DFDEE6" class="T11b" height="25" valign="middle" width="200">廠商名稱</th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
# </td>
# </tr>
# <tr class="award_table_tr_5">
# <th align="left" bgcolor="#DFDEE6" class="T11b" height="25" valign="middle" width="200">廠商地址</th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
# </td>
# </tr>
# <tr class="award_table_tr_5">
# <th align="left" bgcolor="#DFDEE6" class="T11b" valign="middle">
# 			得標廠商<font size="3">8</font>
# </th>
# <td bgcolor="#EFF1F1" class="newstop" height="25"> </td>
# </tr>
# <tr class="award_table_tr_5">
# <th align="left" bgcolor="#DFDEE6" class="T11b" height="25" valign="middle" width="200">廠商代碼</th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
#
#
#
#
# 						70783625
#
#
#
# 		</td>
# </tr>
# <tr class="award_table_tr_5">
# <th align="left" bgcolor="#DFDEE6" class="T11b" height="25" valign="middle" width="200">廠商名稱</th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
# </td>
# </tr>
# <tr class="award_table_tr_5">
# <th align="left" bgcolor="#DFDEE6" class="T11b" height="25" valign="middle" width="200">廠商地址</th>
# <td bgcolor="#EFF1F1" class="newstop" height="25">
# </td>
# </tr>
# <tr class="award_table_tr_5">
# <th align="left" bgcolor="#DFDEE6" class="T11b" valign="middle" width="200">附加說明</th>
# <td bgcolor="#EFF1F1" class="newstop">
# 			Time-limit for Receipt of Tenders Until 2015/05/18 17:○○
# 		</td>
# </tr>
# <!-- delimiter 英文公告 End -->
# <!-- delimiter 決標資料 Start -->
# <tr class="award_table_tr_6">
# <td align="center" bgcolor="#c79961" class="form_head" rowspan="16" valign="middle" width="38">
# <span class="newstop">決<br/>標<br/>資<br/>料</span>
# </td>
# </tr>
# <tr class="award_table_tr_6">
# <th bgcolor="#ddc09e" class="T11b" width="200">決標公告序號</th>
# <td bgcolor="#EFF1F1" class="newstop">
# 			001
# 		</td>
# </tr>
# <tr class="award_table_tr_6">
# <th bgcolor="#ddc09e" class="T11b" width="200">公告更正序號</th>
# <td bgcolor="#EFF1F1" class="newstop">
# <span style="color:red;font-weight:bold" title="前次公告為：000">001</span>
# </td>
# </tr>
# <tr class="award_table_tr_6">
# <th bgcolor="#ddc09e" class="T11b" width="200">決標日期</th>
# <td bgcolor="#EFF1F1" class="newstop">
# 			104/07/15
#
# 		</td>
# </tr>
# <tr class="award_table_tr_6">
# <th bgcolor="#ddc09e" class="T11b" width="200">原決標公告日期</th>
# <td bgcolor="#EFF1F1" class="newstop">
# 		    104/07/24
# 		</td>
# </tr>
# <tr class="award_table_tr_6">
# <th bgcolor="#ddc09e" class="T11b" width="200">決標公告日期</th>
# <td bgcolor="#EFF1F1" class="newstop">
# <span style="color:red;font-weight:bold" title="前次公告為：104/07/24">104/07/28</span>
# </td>
# </tr>
# <tr class="award_table_tr_6">
# <th bgcolor="#ddc09e" class="T11b" width="200">執行現況</th>
# <td bgcolor="#EFF1F1" class="newstop">
#
# 		全案已決標
#  		</td>
# </tr>
# <tr class="award_table_tr_6">
# <th bgcolor="#ddc09e" class="T11b" width="200">是否刊登公報</th>
# <td bgcolor="#EFF1F1" class="newstop">
#
#
#
#
#
#
#
#
#
#
# 			是
# 		</td>
# </tr>
# <tr class="award_table_tr_6">
# <th bgcolor="#ddc09e" class="T11b" width="200">底價金額</th>
# <td bgcolor="#EFF1F1" class="newstop">
# 				16,710,433元
# 			</td>
# </tr>
# <tr class="award_table_tr_6">
# <th bgcolor="#ddc09e" class="T11b" width="200">底價金額是否公開</th>
# <td bgcolor="#EFF1F1" class="newstop">
# 				是
#
# 	                       </td>
# </tr>
# <tr class="award_table_tr_6">
# <th bgcolor="#ddc09e" class="T11b" width="200">總決標金額</th>
# <td bgcolor="#EFF1F1" class="newstop">
# 		    16,584,937元
#
#
# 		</td>
# </tr>
# <tr class="award_table_tr_6">
# <th bgcolor="#ddc09e" class="T11b" width="200">總決標金額是否公開</th>
# <td bgcolor="#EFF1F1" class="newstop">
# 			是
#
# 		</td>
# </tr>
# <!-- 最低標標案才顯示是否依採購法第58條規定採次低標或次次低標決標 -->
# <tr class="award_table_tr_6">
# <th bgcolor="#ddc09e" class="T11b" width="200">契約是否訂有依物價指數調整價金規定</th>
# <td bgcolor="#EFF1F1" class="newstop">
#
#
#
#
#
#
#
#
#
#
# 			否
# 		</td>
# </tr>
# <tr class="award_table_tr_6">
# <th bgcolor="#ddc09e" class="T11b" width="200">未列物價調整規定說明</th>
# <td bgcolor="#EFF1F1" class="newstop">
#                        勞務案
#
#                     </td>
# </tr>
# <tr class="award_table_tr_6">
# <th bgcolor="#ddc09e" class="T11b" width="200">履約執行機關</th>
# <td bgcolor="#EFF1F1" class="newstop">
#
#
#
#
# 			機關代碼：3.13.2<br>機關名稱：經濟部工業局
# 		</br></td>
# </tr>
# <tr class="award_table_tr_6">
# <th bgcolor="#ddc09e" class="T11b" width="200">附加說明</th>
# <td bgcolor="#EFF1F1" class="newstop">
# </td>
# </tr>
# <!-- delimiter 決標資料 End -->
# <!-- delimiter 撤銷公告 Start -->
# <!-- delimiter 撤銷公告 End -->
# </link></link></tbody>
# </table>
# </div>

# %%
from bs4 import BeautifulSoup
f = open('bid_detail.txt', 'w')
soup = BeautifulSoup(res.text)
#f.write(soup.select('#printArea')[0])
#print type(soup.select('#printArea')[0])
detail = soup.select('#printArea')[0].prettify('utf-8')
f.write(detail)
f.close()

# %%
f = open('政府電子採購網.txt', 'r')
response_text = f.read()
f.close()
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-2-96232874f38e> in <module>()
# ----> 1 f = open('政府電子採購網.txt', 'r')
#       2 response_text = f.read()
#       3 f.close()
#
# IOError: [Errno 22] invalid mode ('r') or filename: '\xe6\x94\xbf\xe5\xba\x9c\xe9\x9b\xbb\xe5\xad\x90\xe6\x8e\xa1\xe8\xb3\xbc\xe7\xb6\xb2.txt'

# %%
f = open('gov/51603189_1040202.txt', 'r')
response_text = f.read()
f.close()

# %%
from bs4 import BeautifulSoup as BS
soup = BS(response_text)
for row in soup.select('tr'):
    th = row.select('th')    
    if len(th) > 0 :
        if th[0].text.encode('utf-8').strip() == '機關代碼':
            print row.select('td')[0].text.strip()
# Out:
# 3.13.2

# %%
dic = {"機關代碼":"", "機關名稱":"", "機關地址":"", "聯絡人": "", "聯絡電話": ""}

for row in soup.select('tr.award_table_tr_1'):
    th = row.select('th')
    if len(th) > 0 :
        if th[0].text.encode('utf-8').strip() in dic:
            print row.select('td')[0].text.strip()
# Out:
# 3.13.2
# 經濟部工業局
# 110臺北市信義區信義路路三段41-3號
# 軟體採購辦公室
# (02)66072558

# %%
import sqlite3 as lite 
import sys
con = None
try:
    con = lite.connect('test.db') # connect to database
    cur = con.cursor() # create cursor
    cur.execute('SELECT SQLITE_VERSION()') # select database version 
    data = cur.fetchone() # fetch one data at a time
    print "SQLite version: %s" % data
except lite.Error, e:
    print "Error %s:" % e.args[0] 
    sys.exit(1)
finally:
    if con:
        con.close()
# Out:
# SQLite version: 3.6.21

# %%
import sqlite3 as lite
import sys
con = lite.connect("test.db")
with con:
    cur = con.cursor() # Drop Table If Exisits
    cur.execute("DROP TABLE IF EXISTS PhoneAddress")
    cur.execute("CREATE TABLE PhoneAddress(phone CHAR(10) PRIMARY KEY, address TEXT, name TEXT unique, age INT NOT NULL)")
    cur.execute("INSERT INTO PhoneAddress VALUES('0912173381','United State','Jhon Doe',53)") 
    cur.execute("INSERT INTO PhoneAddress VALUES('0928375018','Tokyo Japan','MuMu Cat',6)") 
    cur.execute("INSERT INTO PhoneAddress VALUES('0957209108','Taipei','Richard',29)") 
    cur.execute("SELECT phone,address FROM PhoneAddress")
    data = cur.fetchall()
    print data
    for rec in data:
        print rec[0], rec[1] 
con.close()
# Out:
# [(u'0912173381', u'United State'), (u'0928375018', u'Tokyo Japan'), (u'0957209108', u'Taipei')]
# 0912173381 United State
# 0928375018 Tokyo Japan
# 0957209108 Taipei

# %%
import requests
from bs4 import BeautifulSoup
res = requests.get('http://www.appledaily.com.tw/realtimenews/section/new/')
soup  = BeautifulSoup(res.text)
for ele in soup.select('.selectorgadget_border'):
    print ele.select('.picword')[0].text, ele.select('span')[0].text
# Out:
# Here Map買主確認！ 德國車廠聯手收購 2015-08-03 11:13
# 為什麼要這樣逼我！9個讓男友起肖的問題 2015-08-03 11:12
# MLB》單局3轟 大都會橫掃國民 2015-08-03 11:12
# 緊盯孩子暑假作業 仁德學童課輔營登場 2015-08-03 11:11
# 蔡正元再轟反課綱 「背宗棄祖、認日作父」 2015-08-03 11:11
# 影片瘋傳  學生建議吳思華「不要走從政這條路」 2015-08-03 11:07
# 愚人節有喜  女歌手捧5月胎 2015-08-03 11:07
# 姊妹通緝多年遭逮 直呼歹路不可行 2015-08-03 11:06
# 自由開講》魔鬼藏身在細節裡 2015-08-03 11:06
# 北管祖師爺聖誕逢父親節 同喜軒勤練扮仙慶祝 2015-08-03 11:06
# 如何「違」調？又「黑箱」？學生發文宣報你知 2015-08-03 11:06
# 張有恒就任華航總經理 2015-08-03 11:03
# 警察直接進課堂找人  原因是… 2015-08-03 11:00
# MLB》光芒新秀邵薩 將缺陣至少一個月 2015-08-03 10:59
# 超獵奇！SHINee遭砍頭 還被打飛眼球 2015-08-03 10:54
# 扮鬼怪搭高鐵 歡慶中元音樂祭 2015-08-03 10:54
# 林冠華母親籲馬總統：請給抗爭孩子溫暖回應 2015-08-03 10:53
# 承認腐敗？中國官媒稱「官場不良風氣未根除」 2015-08-03 10:51
# 政府強推新課綱 徐世榮：洗腦、霸凌 2015-08-03 10:50
# 蝦米樂團樂音飄入花、東安養院 2015-08-03 10:50
# 學甲頑皮世界野生動物園也辦畫展 有「藝」思 2015-08-03 10:49
# 國一南下57公里處車禍 時速僅約30公里 2015-08-03 10:48
# "不愛自己"  星卉抗憂鬱症哭了  2015-08-03 10:47
# 真是佛心來著 普濟寺、龍山寺捐款、捐設備 2015-08-03 10:47
# 自由開講》寫在一條年輕生命殞落之後 2015-08-03 10:46

# %%
import requests
help(requests)
# Out:
# Help on package requests:
#
# NAME
#     requests
#
# FILE
#     c:\python27\lib\site-packages\requests\__init__.py
#
# DESCRIPTION
#     requests HTTP library
#     ~~~~~~~~~~~~~~~~~~~~~
#
#     Requests is an HTTP library, written in Python, for human beings. Basic GET
#     usage:
#
#        >>> import requests
#        >>> r = requests.get('https://www.python.org')
#        >>> r.status_code
#        200
#        >>> 'Python is a programming language' in r.content
#        True
#
#     ... or POST:
#
#        >>> payload = dict(key1='value1', key2='value2')
#        >>> r = requests.post('http://httpbin.org/post', data=payload)
#        >>> print(r.text)
#        {
#          ...
#          "form": {
#            "key2": "value2",
#            "key1": "value1"
#          },
#          ...
#        }
#
#     The other HTTP methods are supported - see `requests.api`. Full documentation
#     is at <http://python-requests.org>.
#
#     :copyright: (c) 2015 by Kenneth Reitz.
#     :license: Apache 2.0, see LICENSE for more details.
#
# PACKAGE CONTENTS
#     adapters
#     api
#     auth
#     certs
#     compat
#     cookies
#     exceptions
#     hooks
#     models
#     packages (package)
#     sessions
#     status_codes
#     structures
#     utils
#
# DATA
#     __author__ = 'Kenneth Reitz'
#     __build__ = 132864
#     __copyright__ = 'Copyright 2015 Kenneth Reitz'
#     __license__ = 'Apache 2.0'
#     __title__ = 'requests'
#     __version__ = '2.7.0'
#     codes = <lookup 'status_codes'>
#
# VERSION
#     2.7.0
#
# AUTHOR
#     Kenneth Reitz

# %%
import requests
from bs4 import BeautifulSoup
header = {'Cookie':'ASP.NET_SessionId=fmznj045mjchdvv5qv3ku1qq; lawbank=afb76860ecf145a191783ee28e729cef-61; _ga=GA1.3.666804656.1439257820; nrhbne=Kv1SuiBH64pvEJpOebtu9Q==; _gat=1; JubFrm-pagebox=%5EcourtFullName%3DKSHV%60%5Ekw%3D%E9%9B%A2%E5%A9%9A%5Ejcatagory%3D0%5Eissimple%3D-1; y=p=jNAUsj23i3gnHRJXg9fMXVFsR4%2fE%2fdlY3EOwcZcf0kizp3FKuVfoa7cjKA3cYnooXMI835cPnKTFr3ImtLivEQ%3d%3d; x=i=Gr+/vOfoSot3xxiYzzcvysCb7FJ4/AZa6j2TetSh7IvQuJOyzoRAHKDxuQ3nidXW&j='}
res = requests.get('http://fyjud.lawbank.com.tw/listcontent5.aspx', headers = header)
#print res.text
soup = BeautifulSoup(res.text)
for ele in soup.select('.Table-List tr td'):
    if len(ele.select('a')) > 0:
        #print ele.text
        #print ele.select('a')[0]['href']
        #print "http://fyjud.lawbank.com.tw/" + ele.select('a')[0]['href']
        res2 = requests.get("http://fyjud.lawbank.com.tw/" + ele.select('a')[0]['href'],headers = header)
        #print res2.text
        f = open('data/'+ele.text + '.txt', 'w')
        f.write(res2.text.encode('utf-8'))
f.close()
